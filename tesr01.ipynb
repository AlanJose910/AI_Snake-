# %% [markdown]
# <a href="https://colab.research.google.com/github/AlanJose910/AI_Snake-/blob/main/tesr01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
import tensorflow as tf

import matplotlib.pyplot as plt
import seaborn as sns

# %%
gpus = tf.config.list_physical_devices('GPU')
cpus = tf.config.list_physical_devices('CPU')
print(gpus)
print(cpus)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
tf.config.set_visible_devices(gpus, 'GPU')

# %%
a = tf.constant([[1.0, 2.0],
                 [3.0, 4.0]])

# %%
# Get the shape of the tensor
shape = a.shape

# Get the number of dimensions (rank) of the tensor
rank = tf.rank(a)

# Get the data type of the elements in the tensor
dtype = a.dtype

# Get the total number of elements in the tensor
num_elements = tf.size(a)


print("Shape:", shape)
print("Rank:", rank)
print("Data Type:", dtype)
print("Number of Elements:", num_elements)
# Out:
# Shape: (2, 2)
# Rank: tf.Tensor(2, shape=(), dtype=int32)
# Data Type: <dtype: 'float32'>
# Number of Elements: tf.Tensor(4, shape=(), dtype=int32)

# %%
#SUBTASK 01

# %%
b = tf.constant([[1.0, 1.0],
                 [1.0, 1.0]]) # Could have also said `tf.ones([2,2])`

print(tf.add(a, b), "\n")
print(tf.multiply(a, b), "\n")
print(tf.matmul(a, b), "\n")
# Out:
# tf.Tensor(
# [[2. 3.]
#  [4. 5.]], shape=(2, 2), dtype=float32)
#
# tf.Tensor(
# [[1. 2.]
#  [3. 4.]], shape=(2, 2), dtype=float32)
#
# tf.Tensor(
# [[3. 3.]
#  [7. 7.]], shape=(2, 2), dtype=float32)

# %%
print("Mean of Tensor a:")
mean_a = tf.reduce_mean(a)
print(mean_a, "\n")

print("Index of Smallest Value in Tensor a:")
index_smallest = tf.argmin(a)
print(index_smallest, "\n")

print("Logarithm of Tensor a:")
log_a = tf.math.log(a)
print(log_a, "\n")

print("Single Value from Tensor a (element at index [0, 1]):")
single_value = a[0, 1]
print(single_value, "\n")

print("Reshaping Tensor a to a new shape (1x4):")
reshaped_a = tf.reshape(a, (1, 4))
print(reshaped_a)
# Out:
# Mean of Tensor a:
# tf.Tensor(2.5, shape=(), dtype=float32)
#
# Index of Smallest Value in Tensor a:
# tf.Tensor([0 0], shape=(2,), dtype=int64)
#
# Logarithm of Tensor a:
# tf.Tensor(
# [[0.        0.6931472]
#  [1.0986123 1.3862944]], shape=(2, 2), dtype=float32)
#
# Single Value from Tensor a (element at index [0, 1]):
# tf.Tensor(2.0, shape=(), dtype=float32)
#
# Reshaping Tensor a to a new shape (1x4):
# tf.Tensor([[1. 2. 3. 4.]], shape=(1, 4), dtype=float32)

# %%
#SUBTASK 1.2

# %%
numpyarray = np.arange(10).reshape(2, 5)
# create a tensorflow variable
a = tf.Variable(numpyarray, dtype=tf.float32)

# %%
#**TODO Your answer here**
#Is tensor 'a' a trainable variable and what does it mean?

#ANSWER: Yes, Because it creates a tenserflow variable  called 'tf.variable'

# %%
# Create variables on CPU
with tf.device('CPU:0'):
    # Define variables a and b
    a = tf.Variable([[5.34, 2.45, 3.4], [4.24, 5.55, 45.9]])
    b = tf.Variable([[1.67, 2.56], [12.3, 23.6], [34.67, 56.7]])

# Perform matrix multiplication on GPU
with tf.device('GPU:0'):
    c = tf.matmul(a, b)

# Print the result
print(c)
# Out:
# tf.Tensor(
# [[ 156.9308   264.27042]
#  [1666.6989  2744.3645 ]], shape=(2, 2), dtype=float32)

# %%
#Subtask 1.3

# %%
data = pd.read_csv('Flood_Data_Classification.csv')
data
# Out:
#       Margarethenklippe  Sennhuette  labels
# 0                   6.5         4.1     0.0
# 1                   6.4         4.1     0.0
# 2                   6.3         3.9     0.0
# 3                   6.3         3.9     0.0
# 4                   6.4         4.1     0.0
# ...                 ...         ...     ...
# 6245                6.9         3.3     0.0
# 6246                6.9         3.4     0.0
# 6247                6.8         3.5     0.0
# 6248                6.7         3.2     0.0
# 6249                6.8         3.1     0.0
#
# [6250 rows x 3 columns]

# %%
print(data.describe)
# Out:
# <bound method NDFrame.describe of       Margarethenklippe  Sennhuette  labels
# 0                   6.5         4.1     0.0
# 1                   6.4         4.1     0.0
# 2                   6.3         3.9     0.0
# 3                   6.3         3.9     0.0
# 4                   6.4         4.1     0.0
# ...                 ...         ...     ...
# 6245                6.9         3.3     0.0
# 6246                6.9         3.4     0.0
# 6247                6.8         3.5     0.0
# 6248                6.7         3.2     0.0
# 6249                6.8         3.1     0.0
#
# [6250 rows x 3 columns]>

# %%
fig, ax = plt.subplots(2, 1, figsize=(8, 5), sharex=True)

ax[0].plot(np.where(data['labels']==0, data['Margarethenklippe'], None), color='tab:blue', label='Normal')
ax[1].plot(np.where(data['labels']==0, data['Sennhuette'], None), color='tab:red', label='Normal')

# Add titles, axis labels, and legend
ax[0].set_title('Margarethenklippe')
ax[0].set_ylabel('Value')
ax[0].legend()

ax[1].set_title('Sennhuette')
ax[1].set_ylabel('Value')
ax[1].legend()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Compute the pairwise correlation matrix
corr = data.corr()

# Plot the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", annot_kws={"size": 12})
plt.title('Pairwise Correlation of Margarethenklippe and Sennhuette')
plt.xlabel('Value')
plt.ylabel('Vlaue')
plt.show()

# %%
import seaborn as sns

sns.pairplot(data)

# %%
#Subtask 1.5

# %%
X = data[['Margarethenklippe', 'Sennhuette']]
y = data['labels']

# %%
print("Statistics of X")
print(X.describe())
# Out:
# Statistics of X
#        Margarethenklippe   Sennhuette
# count        6250.000000  6250.000000
# mean           10.553440     7.821264
# std             6.396791     6.642199
# min             3.700000     1.500000
# 25%             6.800000     4.000000
# 50%             9.050000     6.000000
# 75%            12.400000     9.400000
# max           155.800000   170.400000

# %%
print("Statistics of y:")
print(y.describe())
# Out:
# Statistics of y:
# count    6250.000000
# mean        0.320800
# std         0.466821
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: labels, dtype: float64

# %%
#Subtask 1.6

# %%
np.random.seed(24)
idx = np.arange(len(X))
np.random.shuffle(idx)
X_shuffled = X.iloc[idx]
y_shuffled = y.iloc[idx]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-f6abcf630621> in <cell line: 4>()
#       2 idx = np.arange(len(X))
#       3 np.random.shuffle(idx)
# ----> 4 X_shuffled = X.iloc[idx]
#       5 y_shuffled = y.iloc[idx]
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/tensor.py in __getattr__(self, name)
#     259         tf.experimental.numpy.experimental_enable_numpy_behavior()
#     260       """)
# --> 261     self.__getattribute__(name)
#     262
#     263   @property
#
# AttributeError: 'tensorflow.python.framework.ops.EagerTensor' object has no attribute 'iloc'

# %%
#Subtask 1.7
